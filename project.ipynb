# %%
class library:
    pass

    def __init__(self,books):
        self.books = books



    def show_avail_books(self):
        print("you can get these books from the library")
        print("+++++++++++++++++++++++++++++++++++++++++")
        for book ,borrower in self.books.items():
            if borrower == "free":
                print(book)

    def lend_book(self,requested_book,name):
        if self.books[requested_book] == "free":
            print(
                        
               f'{requested_book} has been marked'
               f' as \'Borrowed\' by: {name}'
               )
            self.books[requested_book]=name
            return True
        
        else:
            print(
                        
               f'Sorry, the {requested_book} is currently'
               f'not avaible : {self.books[requested_book]}'
               )
            return False
            

       



    def return_book():
        pass 




class student:


    def __init__(self,name ,library):
        self.name = name
        self.library = library
        self.books = []
    

    def view_borrowed(self):
        pass 

    
    def request_book(self):
        book = input(
            'Enter the name of the book you\'d like to borrow >>::  ')

        if self.library1.lend_book(book,self.name):
            self.books.append(book)


        


    def return_book(self):
        pass 






def create_mylib():


    books = {
        "python coding ":"free",
        "data science":"free",
        "machine learning":"free"
    }


    library1=library(books)

    student_example =student("your name",library1)


    while True: 
        print("""
              *********** Books in Library ***********
              
              1.Display Available Books
              2.Borrow a Book
              3.Return a Book
              4.View Your Books
              5.Exit 
               """)
        

        choice = int(input("enter your choice"))

        if choice == 1:
            print()
            library1.show_avail_books()

        elif choice == 2:
            print()
            student_example.request_book()




create_mylib()
# Out:
#               *********** Books in Library ***********
#
#               1.Display Available Books
#               2.Borrow a Book
#               3.Return a Book
#               4.View Your Books
#               5.Exit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 117
#     111             print()
#     112             student_example.request_book()
# --> 117 create_mylib()
#
# Cell In[3], line 104, in create_mylib()
#      92 while True:
#      93     print("""
#      94           *********** Books in Library ***********
#      95
#    (...)
#     100           5.Exit
#     101            """)
# --> 104     choice = int(input("enter your choice"))
#     106     if choice == 1:
#     107         print()
#
# ValueError: invalid literal for int() with base 10: ''
