# %%
class library:
    

    def __init__(self, books ):
        self.books = books 


    def show_avail_books(self):
        print("these books are available in library")
        print("++++++++++++++++++++++++++++++++")
        for book, borrower in self.books.itmes():
            if borrower  == "free":
                print(book)


    def lend_book():
        pass


    def return_book():
        pass




class student :
    

    def __init__(self, name , library):
        self.name = name 
        self.library = library
        self.books=[]


    def view_borrowed(self):
        pass


    def request_book(self):
        pass

    def return_book(self):
        pass 




def create_lib():

    books={
        "python coding ":"free",
        "data science":"free",
        "machine learning":"free"
    } 

    library1 = library(books)
    student_sample = student("your name", library=library1)




    while True:

        print("""
              *********** books in library ***********")
        1. Available books
        2. borrow books 
        3. return books 
        4. view your books 
        5. exit 
              

      """)
        
        choice = int(input("select your choice: "))

        if choice ==1:
            print()
            library1.show_avail_books()
        elif choice ==2:
            print()

        elif choice ==3:
            print()

        elif choice ==4:
            print()

        elif choice ==5:
            print("thank for using library")
            exit()


create_lib()
# Out:
#               *********** books in library ***********")
#         1. Available books
#         2. borrow books
#         3. return books
#         4. view your books
#         5. exit
#
#
#
#
# these books are available in library
# ++++++++++++++++++++++++++++++++
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 94
#      90             print("thank for using library")
#      91             exit()
# ---> 94 create_lib()
#
# Cell In[7], line 79, in create_lib()
#      77 if choice ==1:
#      78     print()
# ---> 79     library1.show_avail_books()
#      80 elif choice ==2:
#      81     print()
#
# Cell In[7], line 11, in library.show_avail_books(self)
#       9 print("these books are available in library")
#      10 print("++++++++++++++++++++++++++++++++")
# ---> 11 for book, borrower in self.books.itmes():
#      12     if borrower  == "free":
#      13         print(book)
#
# AttributeError: 'dict' object has no attribute 'itmes'

# %%
class Library:
    

    def __init__(self, books ):
        self.books = books 


    def show_avail_books(self):
        print("These books are available in the library")
        print("++++++++++++++++++++++++++++++++")
        for book, borrower in self.books.items():
            if borrower  == "free":
                print(book)


def create_lib():

    books={
        "python coding": "free",
        "data science": "free",
        "machine learning": "free"
    } 

    library1 = Library(books)

    while True:

        print("""
              *********** Books in Library ***********")
        1. Available books
        2. Borrow books 
        3. Return books 
        4. View your books 
        5. Exit 
              

      """)
        
        choice = int(input("Select your choice: "))

        if choice == 1:
            print()
            library1.show_avail_books()
        elif choice == 2:
            print()
            # Implement the borrowing functionality here
        elif choice == 3:
            print()
            # Implement the returning functionality here
        elif choice == 4:
            print()
            # Implement the viewing borrowed books functionality here
        elif choice == 5:
            print("Thank you for using the library.")
            exit()


create_lib()
# Out:
#               *********** Books in Library ***********")
#         1. Available books
#         2. Borrow books
#         3. Return books
#         4. View your books
#         5. Exit
#
#
#
#
# These books are available in the library
# ++++++++++++++++++++++++++++++++
# python coding
# data science
# machine learning
#
#               *********** Books in Library ***********")
#         1. Available books
#         2. Borrow books
#         3. Return books
#         4. View your books
#         5. Exit

# %%
class Library:
    
    def __init__(self, books):
        self.books = books 

    def show_avail_books(self):
        print("These books are available in the library")
        print("++++++++++++++++++++++++++++++++")
        for book, borrower in self.books.items():
            if borrower == "free":
                print(book)

    def lend_book(self, requested_book, borrower_name):
        # Check if the requested book exists in the library
        if requested_book in self.books:
            # If the book is available, mark it as borrowed
            if self.books[requested_book] == "free":
                print(
                    f'{requested_book} has been marked as \'Borrowed\' by: {borrower_name}')
                self.books[requested_book] = borrower_name
                return True
            else:
                # If the book is already borrowed, print a message
                print(
                    f'Sorry, the {requested_book} is currently on loan to: {self.books[requested_book]}')
                return False
        else:
            # If the requested book is not found in the library, print an error message
            print(f'Sorry, the {requested_book} is not available in the library')
            return False

class Student:
    
    def __init__(self, name, library):
        self.name = name 
        self.library = library
        self.books = []

    def request_book(self, book_name):
        if self.library.lend_book(book_name, self.name):
            self.books.append(book_name)

def create_lib():
    books = {
        "python coding": "free",
        "data science": "free",
        "machine learning": "free"
    } 

    library1 = Library(books)
    student1 = Student("Your Name", library=library1)

    while True:

        print("""
              *********** Books in Library ***********
        1. Available books
        2. Borrow books 
        3. Exit 
              

      """)
        
        choice = int(input("Select your choice: "))

        if choice == 1:
            print()
            library1.show_avail_books()
        elif choice == 2:
            print()
            book_name = input("Enter the name of the book you want to borrow: ")
            student1.request_book(book_name)
        elif choice == 3:
            print("Thank you for using the library.")
            exit()

create_lib()
# Out:
#               *********** Books in Library ***********
#         1. Available books
#         2. Borrow books
#         3. Exit
#
#
#
#
# These books are available in the library
# ++++++++++++++++++++++++++++++++
# python coding
# data science
# machine learning
#
#               *********** Books in Library ***********
#         1. Available books
#         2. Borrow books
#         3. Exit
#
#
#
#
# data science has been marked as 'Borrowed' by: Your Name
#
#               *********** Books in Library ***********
#         1. Available books
#         2. Borrow books
#         3. Exit

# %%
class Library:
    
    def __init__(self, books):
        self.books = books 

    def show_avail_books(self):
        print("These books are available in the library")
        print("++++++++++++++++++++++++++++++++")
        for book, borrower in self.books.items():
            if borrower == "free":
                print(book)

    def lend_book(self, requested_book, borrower_name):
        # Check if the requested book exists in the library
        if requested_book in self.books:
            # If the book is available, mark it as borrowed
            if self.books[requested_book] == "free":
                print(
                    f'{requested_book} has been marked as \'Borrowed\' by: {borrower_name}')
                self.books[requested_book] = borrower_name
                return True
            else:
                # If the book is already borrowed, print a message
                print(
                    f'Sorry, the {requested_book} is currently on loan to: {self.books[requested_book]}')
                return False
        else:
            # If the requested book is not found in the library, print an error message
            print(f'Sorry, the {requested_book} is not available in the library')
            return False

class Student:
    
    def __init__(self, name, library):
        self.name = name 
        self.library = library
        self.books = []

    def request_book(self, book_name):
        if self.library.lend_book(book_name, self.name):
            self.books.append(book_name)



    def view_borrowed(self):
       if not self.books:
           print('You haven\'t borrowed any books')
       else:
           for book in self.books:
               print(book)

def create_lib():
    books = {
        "python coding": "free",
        "data science": "free",
        "machine learning": "free"
    } 

    library1 = Library(books)
    student1 = Student("Your Name", library=library1)

    while True:

        print("""
              *********** Books in Library ***********
        1. Available books
        2. Borrow books 
        3. Exit 
              

      """)
        
        choice = int(input("Select your choice: "))

        if choice == 1:
            print()
            library1.show_avail_books()
        elif choice == 2:
            print()
            book_name = input("Enter the name of the book you want to borrow: ")
            student1.request_book(book_name)
        elif choice ==3:
            print()
            student1.view_borrowed()

        elif choice == 4:
            print("Thank you for using the library.")
            exit()

create_lib()
# Out:
#               *********** Books in Library ***********
#         1. Available books
#         2. Borrow books
#         3. Exit
#
#
#
#
# These books are available in the library
# ++++++++++++++++++++++++++++++++
# python coding
# data science
# machine learning
#
#               *********** Books in Library ***********
#         1. Available books
#         2. Borrow books
#         3. Exit
#
#
#
#
# data science has been marked as 'Borrowed' by: Your Name
#
#               *********** Books in Library ***********
#         1. Available books
#         2. Borrow books
#         3. Exit
#
#
#
#
# data science
#
#               *********** Books in Library ***********
#         1. Available books
#         2. Borrow books
#         3. Exit
#
#
#
# Thank you for using the library.
#
#               *********** Books in Library ***********
#         1. Available books
#         2. Borrow books
#         3. Exit
#
#
#
# Thank you for using the library.
#
#               *********** Books in Library ***********
#         1. Available books
#         2. Borrow books
#         3. Exit
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
class Library:
    
    def __init__(self, books):
        self.books = books 

    def show_avail_books(self):
        print("These books are available in the library")
        print("++++++++++++++++++++++++++++++++")
        for book, borrower in self.books.items():
            if borrower == "free":
                print(book)

    def lend_book(self, requested_book, borrower_name):
        # Check if the requested book exists in the library
        if requested_book in self.books:
            # If the book is available, mark it as borrowed
            if self.books[requested_book] == "free":
                print(
                    f'{requested_book} has been marked as \'Borrowed\' by: {borrower_name}')
                self.books[requested_book] = borrower_name
                return True
            else:
                # If the book is already borrowed, print a message
                print(
                    f'Sorry, the {requested_book} is currently on loan to: {self.books[requested_book]}')
                return False
        else:
            # If the requested book is not found in the library, print an error message
            print(f'Sorry, the {requested_book} is not available in the library')
            return False

    def return_book(self, returned_book):
        if returned_book in self.books and self.books[returned_book] != "free":
            print(f'Thanks for returning {returned_book}')
            self.books[returned_book] = "free"
        else:
            print(f'Error: {returned_book} is not a valid book or is not borrowed')

class Student:
    
    def __init__(self, name, library):
        self.name = name 
        self.library = library
        self.books = []

    def request_book(self, book_name):
        if self.library.lend_book(book_name, self.name):
            self.books.append(book_name)

    def return_book(self, book_name):
        if book_name in self.books:
            self.library.return_book(book_name)
            self.books.remove(book_name)
        else:
            print(f'Error: {book_name} is not borrowed by {self.name}')

    def view_borrowed(self):
        if not self.books:
            print('You haven\'t borrowed any books')
        else:
            print('Books you have borrowed:')
            for book in self.books:
                print(book)

def create_lib():
    books = {
        "python coding": "free",
        "data science": "free",
        "machine learning": "free"
    } 

    library1 = Library(books)
    student1 = Student("Your Name", library=library1)

    while True:

        print("""
              *********** Books in Library ***********
        1. Available books
        2. Borrow books 
        3. Return books
        4. View your borrowed books
        5. Exit 
              

      """)
        
        choice = int(input("Select your choice: "))

        if choice == 1:
            print()
            library1.show_avail_books()
        elif choice == 2:
            print()
            book_name = input("Enter the name of the book you want to borrow: ")
            student1.request_book(book_name)
        elif choice == 3:
            print()
            book_name = input("Enter the name of the book you want to return: ")
            student1.return_book(book_name)
        elif choice == 4:
            print()
            student1.view_borrowed()
        elif choice == 5:
            print("Thank you for using the library.")
            exit()

create_lib()
# Out:
#               *********** Books in Library ***********
#         1. Available books
#         2. Borrow books
#         3. Return books
#         4. View your borrowed books
#         5. Exit
#
#
#
#
# These books are available in the library
# ++++++++++++++++++++++++++++++++
# python coding
# data science
# machine learning
#
#               *********** Books in Library ***********
#         1. Available books
#         2. Borrow books
#         3. Return books
#         4. View your borrowed books
#         5. Exit
#
#
#
#
# Sorry, the data science  is not available in the library
#
#               *********** Books in Library ***********
#         1. Available books
#         2. Borrow books
#         3. Return books
#         4. View your borrowed books
#         5. Exit
#
#
#
#
# data science has been marked as 'Borrowed' by: Your Name
#
#               *********** Books in Library ***********
#         1. Available books
#         2. Borrow books
#         3. Return books
#         4. View your borrowed books
#         5. Exit
#
#
#
#
# Books you have borrowed:
# data science
#
#               *********** Books in Library ***********
#         1. Available books
#         2. Borrow books
#         3. Return books
#         4. View your borrowed books
#         5. Exit
#
#
#
# Thank you for using the library.
#
#               *********** Books in Library ***********
#         1. Available books
#         2. Borrow books
#         3. Return books
#         4. View your borrowed books
#         5. Exit
#
#
#
# Thank you for using the library.
#
#               *********** Books in Library ***********
#         1. Available books
#         2. Borrow books
#         3. Return books
#         4. View your borrowed books
#         5. Exit

# %%
class library :

    def __init__(self,books):
        self.books = books 


    def show_available_books(self):
        print("These books are available in the library")
        print("+++++++++++===============+++++++++++")
        for book ,borrower in self.books.items():
            if borrower == "free":
                print(book)


    def lend_book(self,requested_book,borrower_name):
        if requested_book in self.books:  
            if self.books[requested_book] == "free":
                print(
                    f'{requested_book} has been marked as \'Borrowed\' by: {borrower_name}')
                self.books[requested_book] = borrower_name
                return True 
            else:
                print(
                    f'sorry this is not available{self.books[requested_book]}')
                return False
    



    def return_book (self,retured_book):
        if retured_book in self.books and self.books[retured_book] != "free":
            print(f'Thanks for returning {retured_book}')
            self.books[retured_book] = "free"
        else:
            print(f'Error: {retured_book} is not a valid book or is not borrowed')


                


                


       




class student :
    def __init__(self,name,library):
        self.name = name 
        self.library = library
        self.books = []



    def request_book (self, book_name):
        if self.library.lend_book(book_name,self.name):
            self.books.append(book_name)



    def return_book(self,book_name):
        if book_name in self.books:
            self.library.return_book(book_name)
            self.books.remove(book_name)
        else:
            print(f'Error: {book_name} is not borrowed by {self.name}')

    

    def view_borrowed(self):
        if not self.books:
            print("you haven't borrowed any books")
        else:
            print("books you have borrowed")
            for book in self.books:
                print(book)




    




def create_lib():

    books={
        "python coding": "free",
        "data science": "free",
        "machine learning": "free" 

    }


    library1 = library(books)
    student1 = student("your name ",library=library1)


    while True :
        print("""

              *********** Books in Library ***********
            1.Availeble books
            2.borrow books 
            3.Return books
            4.View your borrowed books
            5.Exit
        

        """)

        choice = int(input("select your choide :"))


        if choice == 1:
            print()
            library1.show_available_books()

        elif choice == 2:
            print()
            book_name =input("enter the name of the book you want to borrow :  ")
            student1.request_book(book_name)



        elif choice == 3 :
            print()
            student1.view_borrowed()



        elif choice == 4:
            print()
            book_name = input("Enter the name of the book you want to return: ")
            student1.return_book(book_name)

        elif choice == 5:
            print("thank you for using the library ")
            exit()








create_lib()
# Out:
#               *********** Books in Library ***********
#             1.Availeble books
#             2.borrow books
#             3.Return books
#             4.View your borrowed books
#             5.Exit
#
#
#
#
# These books are available in the library
# +++++++++++===============+++++++++++
# python coding
# data science
# machine learning
#
#
#               *********** Books in Library ***********
#             1.Availeble books
#             2.borrow books
#             3.Return books
#             4.View your borrowed books
#             5.Exit
#
#
#
#
#
#
#               *********** Books in Library ***********
#             1.Availeble books
#             2.borrow books
#             3.Return books
#             4.View your borrowed books
#             5.Exit
